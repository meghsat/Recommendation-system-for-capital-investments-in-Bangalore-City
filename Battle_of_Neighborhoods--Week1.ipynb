# %% [markdown]
# # Peer-graded Assignment: Capstone Project - The Battle of Neighborhoods (Week 1)

# %% [markdown]
# ### Rental Analysis of Banglore City Using Various Parameters.

# %% [markdown]
# #### Introduction/Business Problem section

# %% [markdown]
# ## Scenario 1:--

# %% [markdown]
# consider you are moving to bangalore for job settlement and this is the first time you are visiting Bangalore.you might not be aware of bangalore and didn't have any connections there so it will be very difficult for you to settle there. So to tackle this problem we shall use Machine Learning Algorithms alongside with Foursquare API to get the details of various appartments in bangalore along with their precise Latitudes and Longitudes(available Below).
# Now for choosing for a best appartment you need to consider the following facts:
# 1. Are there any Restaurants Available nearby to Appartment?.
# 2. are there any cafe's nearby?
# 3. What are the parameters affecting price hikes?
# 4. Are they "ready to move"?, If not when can i move to those Apprtments?
# 5. what is the square feet of the appartment?
# 6. in what distance can i find a badminton court from my appartment?

# %% [markdown]
# ## Interested Audience

# %% [markdown]
# People who are newly moving to bangalore can easily search for appartments based on various search filters. this can be useful when you are vacating old house and searching for a new one.

# %%
import os # Operating System
import numpy as np
import pandas as pd
import datetime as dt # Datetime
import json # library to handle JSON files

#!conda install -c conda-forge geopy --yes
from geopy.geocoders import Nominatim # convert an address into latitude and longitude values

import requests # library to handle requests
from pandas.io.json import json_normalize # tranform JSON file into a pandas dataframe

# Matplotlib and associated plotting modules
import matplotlib.cm as cm
import matplotlib.colors as colors

#!conda install -c conda-forge folium=0.5.0 --yes
import folium #import folium # map rendering library

# %%
df_bglr=pd.read_csv("Bengaluru_House_Data.csv")
df_bglr
# Out:
#                   area_type   availability                  location  \
# 0      Super built-up  Area         19-Dec  Electronic City Phase II
# 1                Plot  Area  Ready To Move          Chikka Tirupathi
# 2            Built-up  Area  Ready To Move               Uttarahalli
# 3      Super built-up  Area  Ready To Move        Lingadheeranahalli
# 4      Super built-up  Area  Ready To Move                  Kothanur
# 5      Super built-up  Area  Ready To Move                Whitefield
# 6      Super built-up  Area         18-May          Old Airport Road
# 7      Super built-up  Area  Ready To Move              Rajaji Nagar
# 8      Super built-up  Area  Ready To Move              Marathahalli
# 9                Plot  Area  Ready To Move              Gandhi Bazar
# 10     Super built-up  Area         18-Feb                Whitefield
# 11               Plot  Area  Ready To Move                Whitefield
# 12     Super built-up  Area  Ready To Move        7th Phase JP Nagar
# 13           Built-up  Area  Ready To Move                 Gottigere
# 14               Plot  Area  Ready To Move                  Sarjapur
# 15     Super built-up  Area  Ready To Move               Mysore Road
# 16     Super built-up  Area  Ready To Move             Bisuvanahalli
# 17     Super built-up  Area  Ready To Move     Raja Rajeshwari Nagar
# 18     Super built-up  Area  Ready To Move     Ramakrishnappa Layout
# 19     Super built-up  Area  Ready To Move        Manayata Tech Park
# 20           Built-up  Area  Ready To Move                   Kengeri
# 21     Super built-up  Area         19-Dec                Binny Pete
# 22               Plot  Area  Ready To Move               Thanisandra
# 23     Super built-up  Area  Ready To Move                 Bellandur
# 24     Super built-up  Area         18-Nov               Thanisandra
# 25     Super built-up  Area         18-May           Mangammanapalya
# 26     Super built-up  Area  Ready To Move           Electronic City
# 27           Built-up  Area         20-Dec                Whitefield
# 28     Super built-up  Area         17-Oct          Ramagondanahalli
# 29     Super built-up  Area  Ready To Move           Electronic City
# ...                     ...            ...                       ...
# 13290  Super built-up  Area  Ready To Move            Sarjapur  Road
# 13291            Plot  Area         18-Jan            Weavers Colony
# 13292  Super built-up  Area         18-Jul          Udayapur Village
# 13293  Super built-up  Area  Ready To Move            Sarjapur  Road
# 13294  Super built-up  Area  Ready To Move             Sultan Palaya
# 13295  Super built-up  Area         18-Feb              Haralur Road
# 13296  Super built-up  Area  Ready To Move                  Cox Town
# 13297  Super built-up  Area  Ready To Move           Electronic City
# 13298  Super built-up  Area  Ready To Move             Kenchenahalli
# 13299  Super built-up  Area         18-Dec                Whitefield
# 13300            Plot  Area  Ready To Move             Hosakerehalli
# 13301  Super built-up  Area  Ready To Move                  Kothanur
# 13302  Super built-up  Area  Ready To Move      Annaiah Reddy Layout
# 13303            Plot  Area  Ready To Move            Vidyaranyapura
# 13304  Super built-up  Area  Ready To Move     Raja Rajeshwari Nagar
# 13305          Carpet  Area  Ready To Move                  Hulimavu
# 13306            Plot  Area  Ready To Move     Rajarajeshwari Nagara
# 13307        Built-up  Area  Ready To Move              Billekahalli
# 13308        Built-up  Area  Ready To Move         Bannerghatta Road
# 13309  Super built-up  Area  Ready To Move              Yeshwanthpur
# 13310  Super built-up  Area  Ready To Move              Rachenahalli
# 13311            Plot  Area  Ready To Move          Ramamurthy Nagar
# 13312  Super built-up  Area  Ready To Move                 Bellandur
# 13313  Super built-up  Area  Ready To Move               Uttarahalli
# 13314  Super built-up  Area  Ready To Move         Green Glen Layout
# 13315        Built-up  Area  Ready To Move                Whitefield
# 13316  Super built-up  Area  Ready To Move             Richards Town
# 13317        Built-up  Area  Ready To Move     Raja Rajeshwari Nagar
# 13318  Super built-up  Area         18-Jun           Padmanabhanagar
# 13319  Super built-up  Area  Ready To Move              Doddathoguru
#
#             size  society   total_sqft  bath  balcony   price
# 0          2 BHK  Coomee          1056   2.0      1.0   39.07
# 1      4 Bedroom  Theanmp         2600   5.0      3.0  120.00
# 2          3 BHK      NaN         1440   2.0      3.0   62.00
# 3          3 BHK  Soiewre         1521   3.0      1.0   95.00
# 4          2 BHK      NaN         1200   2.0      1.0   51.00
# 5          2 BHK  DuenaTa         1170   2.0      1.0   38.00
# 6          4 BHK  Jaades          2732   4.0      NaN  204.00
# 7          4 BHK  Brway G         3300   4.0      NaN  600.00
# 8          3 BHK      NaN         1310   3.0      1.0   63.25
# 9      6 Bedroom      NaN         1020   6.0      NaN  370.00
# 10         3 BHK      NaN         1800   2.0      2.0   70.00
# 11     4 Bedroom  Prrry M         2785   5.0      3.0  295.00
# 12         2 BHK  Shncyes         1000   2.0      1.0   38.00
# 13         2 BHK      NaN         1100   2.0      2.0   40.00
# 14     3 Bedroom  Skityer         2250   3.0      2.0  148.00
# 15         2 BHK  PrntaEn         1175   2.0      2.0   73.50
# 16         3 BHK  Prityel         1180   3.0      2.0   48.00
# 17         3 BHK  GrrvaGr         1540   3.0      3.0   60.00
# 18         3 BHK  PeBayle         2770   4.0      2.0  290.00
# 19         2 BHK      NaN         1100   2.0      2.0   48.00
# 20         1 BHK      NaN          600   1.0      1.0   15.00
# 21         3 BHK  She 2rk         1755   3.0      1.0  122.00
# 22     4 Bedroom  Soitya          2800   5.0      2.0  380.00
# 23         3 BHK      NaN         1767   3.0      1.0  103.00
# 24          1 RK  Bhe 2ko          510   1.0      0.0   25.25
# 25         3 BHK      NaN         1250   3.0      2.0   56.00
# 26         2 BHK  Itelaa           660   1.0      1.0   23.10
# 27         3 BHK      NaN         1610   3.0      2.0   81.00
# 28         2 BHK  ViistLa         1151   2.0      2.0   48.77
# 29         3 BHK  KBityo          1025   2.0      1.0   47.00
# ...          ...      ...          ...   ...      ...     ...
# 13290      4 BHK  Maana E         4050   2.0      1.0  450.00
# 13291  1 Bedroom      NaN          812   1.0      0.0   26.00
# 13292      3 BHK  Plowsri         1440   2.0      2.0   63.93
# 13293      4 BHK  Puallhi         2425   5.0      1.0  195.00
# 13294      4 BHK  RSntsAp         2200   3.0      3.0   80.00
# 13295      3 BHK  SNnia E         1810   3.0      2.0  112.00
# 13296      2 BHK      NaN         1200   2.0      2.0  140.00
# 13297      2 BHK  GMown E         1060   2.0      1.0   52.00
# 13298      2 BHK  AriosPa         1015   2.0      2.0   60.00
# 13299      4 BHK  Prtates  2830 - 2882   5.0      0.0  154.50
# 13300  5 Bedroom      NaN         1500   6.0      2.0  145.00
# 13301      3 BHK      NaN         1454   3.0      3.0   71.50
# 13302      2 BHK      NaN         1075   2.0      2.0   48.00
# 13303  5 Bedroom      NaN          774   5.0      3.0   70.00
# 13304      2 BHK  GrrvaGr         1187   2.0      2.0   40.14
# 13305      1 BHK      NaN          500   1.0      3.0  220.00
# 13306  4 Bedroom      NaN         1200   5.0      NaN  325.00
# 13307      3 BHK      NaN         1805   3.0      3.0  134.00
# 13308      3 BHK  Baanise         1527   3.0      1.0  142.00
# 13309      3 BHK  IBityin         1675   3.0      NaN   92.13
# 13310      2 BHK      NaN         1050   2.0      2.0   52.71
# 13311  7 Bedroom      NaN         1500   9.0      2.0  250.00
# 13312      2 BHK      NaN         1262   2.0      2.0   47.00
# 13313      3 BHK  Aklia R         1345   2.0      1.0   57.00
# 13314      3 BHK  SoosePr         1715   3.0      3.0  112.00
# 13315  5 Bedroom  ArsiaEx         3453   4.0      0.0  231.00
# 13316      4 BHK      NaN         3600   5.0      NaN  400.00
# 13317      2 BHK  Mahla T         1141   2.0      1.0   60.00
# 13318      4 BHK  SollyCl         4689   4.0      1.0  488.00
# 13319      1 BHK      NaN          550   1.0      1.0   17.00
#
# [13320 rows x 9 columns]

# %% [markdown]
# ## Scenario 2:-

# %% [markdown]
# Consider you are willing to establish a new restaurant business in bangalore city and looking for very minimum competition to tackle the problem we shall use Machine Learning to get you the best suitable areas to establish your restaurant based on other filters like:
# 1. is it Ready to move?
# 2. How many rooms are available?
# 3. Square feet of the area
# 4. is it near to any badminton court?

# %% [markdown]
# ## Interested Audience

# %% [markdown]
# businessman who are willing to establish a chinese restaurant need to check whether any chinese restaurant is already available or not, if so what are the ratings of the current one.
# people willing to open a new badminton court should check whether any courts are already available or not

# %% [markdown]
# # Data Sets :

# %% [markdown]
# ### Description of the data  that will be used to solve the problem

# %% [markdown]
# For my project i will be using "https://www.kaggle.com/amitabhajoy/bengaluru-house-price-data" Bengalure housing price dataset. the only problem with this dataset is the **latitudes and longitudes** are not available so we need to pass each location through foursqaure and need to extract the latitude and longitudes this is a tiresome and very much time taking so i am only taking 600 rows out of the dataset

# %%
df_bglr
# Out:
#                   area_type   availability                  location  \
# 0      Super built-up  Area         19-Dec  Electronic City Phase II
# 1                Plot  Area  Ready To Move          Chikka Tirupathi
# 2            Built-up  Area  Ready To Move               Uttarahalli
# 3      Super built-up  Area  Ready To Move        Lingadheeranahalli
# 4      Super built-up  Area  Ready To Move                  Kothanur
# 5      Super built-up  Area  Ready To Move                Whitefield
# 6      Super built-up  Area         18-May          Old Airport Road
# 7      Super built-up  Area  Ready To Move              Rajaji Nagar
# 8      Super built-up  Area  Ready To Move              Marathahalli
# 9                Plot  Area  Ready To Move              Gandhi Bazar
# 10     Super built-up  Area         18-Feb                Whitefield
# 11               Plot  Area  Ready To Move                Whitefield
# 12     Super built-up  Area  Ready To Move        7th Phase JP Nagar
# 13           Built-up  Area  Ready To Move                 Gottigere
# 14               Plot  Area  Ready To Move                  Sarjapur
# 15     Super built-up  Area  Ready To Move               Mysore Road
# 16     Super built-up  Area  Ready To Move             Bisuvanahalli
# 17     Super built-up  Area  Ready To Move     Raja Rajeshwari Nagar
# 18     Super built-up  Area  Ready To Move     Ramakrishnappa Layout
# 19     Super built-up  Area  Ready To Move        Manayata Tech Park
# 20           Built-up  Area  Ready To Move                   Kengeri
# 21     Super built-up  Area         19-Dec                Binny Pete
# 22               Plot  Area  Ready To Move               Thanisandra
# 23     Super built-up  Area  Ready To Move                 Bellandur
# 24     Super built-up  Area         18-Nov               Thanisandra
# 25     Super built-up  Area         18-May           Mangammanapalya
# 26     Super built-up  Area  Ready To Move           Electronic City
# 27           Built-up  Area         20-Dec                Whitefield
# 28     Super built-up  Area         17-Oct          Ramagondanahalli
# 29     Super built-up  Area  Ready To Move           Electronic City
# ...                     ...            ...                       ...
# 13290  Super built-up  Area  Ready To Move            Sarjapur  Road
# 13291            Plot  Area         18-Jan            Weavers Colony
# 13292  Super built-up  Area         18-Jul          Udayapur Village
# 13293  Super built-up  Area  Ready To Move            Sarjapur  Road
# 13294  Super built-up  Area  Ready To Move             Sultan Palaya
# 13295  Super built-up  Area         18-Feb              Haralur Road
# 13296  Super built-up  Area  Ready To Move                  Cox Town
# 13297  Super built-up  Area  Ready To Move           Electronic City
# 13298  Super built-up  Area  Ready To Move             Kenchenahalli
# 13299  Super built-up  Area         18-Dec                Whitefield
# 13300            Plot  Area  Ready To Move             Hosakerehalli
# 13301  Super built-up  Area  Ready To Move                  Kothanur
# 13302  Super built-up  Area  Ready To Move      Annaiah Reddy Layout
# 13303            Plot  Area  Ready To Move            Vidyaranyapura
# 13304  Super built-up  Area  Ready To Move     Raja Rajeshwari Nagar
# 13305          Carpet  Area  Ready To Move                  Hulimavu
# 13306            Plot  Area  Ready To Move     Rajarajeshwari Nagara
# 13307        Built-up  Area  Ready To Move              Billekahalli
# 13308        Built-up  Area  Ready To Move         Bannerghatta Road
# 13309  Super built-up  Area  Ready To Move              Yeshwanthpur
# 13310  Super built-up  Area  Ready To Move              Rachenahalli
# 13311            Plot  Area  Ready To Move          Ramamurthy Nagar
# 13312  Super built-up  Area  Ready To Move                 Bellandur
# 13313  Super built-up  Area  Ready To Move               Uttarahalli
# 13314  Super built-up  Area  Ready To Move         Green Glen Layout
# 13315        Built-up  Area  Ready To Move                Whitefield
# 13316  Super built-up  Area  Ready To Move             Richards Town
# 13317        Built-up  Area  Ready To Move     Raja Rajeshwari Nagar
# 13318  Super built-up  Area         18-Jun           Padmanabhanagar
# 13319  Super built-up  Area  Ready To Move              Doddathoguru
#
#             size  society   total_sqft  bath  balcony   price
# 0          2 BHK  Coomee          1056   2.0      1.0   39.07
# 1      4 Bedroom  Theanmp         2600   5.0      3.0  120.00
# 2          3 BHK      NaN         1440   2.0      3.0   62.00
# 3          3 BHK  Soiewre         1521   3.0      1.0   95.00
# 4          2 BHK      NaN         1200   2.0      1.0   51.00
# 5          2 BHK  DuenaTa         1170   2.0      1.0   38.00
# 6          4 BHK  Jaades          2732   4.0      NaN  204.00
# 7          4 BHK  Brway G         3300   4.0      NaN  600.00
# 8          3 BHK      NaN         1310   3.0      1.0   63.25
# 9      6 Bedroom      NaN         1020   6.0      NaN  370.00
# 10         3 BHK      NaN         1800   2.0      2.0   70.00
# 11     4 Bedroom  Prrry M         2785   5.0      3.0  295.00
# 12         2 BHK  Shncyes         1000   2.0      1.0   38.00
# 13         2 BHK      NaN         1100   2.0      2.0   40.00
# 14     3 Bedroom  Skityer         2250   3.0      2.0  148.00
# 15         2 BHK  PrntaEn         1175   2.0      2.0   73.50
# 16         3 BHK  Prityel         1180   3.0      2.0   48.00
# 17         3 BHK  GrrvaGr         1540   3.0      3.0   60.00
# 18         3 BHK  PeBayle         2770   4.0      2.0  290.00
# 19         2 BHK      NaN         1100   2.0      2.0   48.00
# 20         1 BHK      NaN          600   1.0      1.0   15.00
# 21         3 BHK  She 2rk         1755   3.0      1.0  122.00
# 22     4 Bedroom  Soitya          2800   5.0      2.0  380.00
# 23         3 BHK      NaN         1767   3.0      1.0  103.00
# 24          1 RK  Bhe 2ko          510   1.0      0.0   25.25
# 25         3 BHK      NaN         1250   3.0      2.0   56.00
# 26         2 BHK  Itelaa           660   1.0      1.0   23.10
# 27         3 BHK      NaN         1610   3.0      2.0   81.00
# 28         2 BHK  ViistLa         1151   2.0      2.0   48.77
# 29         3 BHK  KBityo          1025   2.0      1.0   47.00
# ...          ...      ...          ...   ...      ...     ...
# 13290      4 BHK  Maana E         4050   2.0      1.0  450.00
# 13291  1 Bedroom      NaN          812   1.0      0.0   26.00
# 13292      3 BHK  Plowsri         1440   2.0      2.0   63.93
# 13293      4 BHK  Puallhi         2425   5.0      1.0  195.00
# 13294      4 BHK  RSntsAp         2200   3.0      3.0   80.00
# 13295      3 BHK  SNnia E         1810   3.0      2.0  112.00
# 13296      2 BHK      NaN         1200   2.0      2.0  140.00
# 13297      2 BHK  GMown E         1060   2.0      1.0   52.00
# 13298      2 BHK  AriosPa         1015   2.0      2.0   60.00
# 13299      4 BHK  Prtates  2830 - 2882   5.0      0.0  154.50
# 13300  5 Bedroom      NaN         1500   6.0      2.0  145.00
# 13301      3 BHK      NaN         1454   3.0      3.0   71.50
# 13302      2 BHK      NaN         1075   2.0      2.0   48.00
# 13303  5 Bedroom      NaN          774   5.0      3.0   70.00
# 13304      2 BHK  GrrvaGr         1187   2.0      2.0   40.14
# 13305      1 BHK      NaN          500   1.0      3.0  220.00
# 13306  4 Bedroom      NaN         1200   5.0      NaN  325.00
# 13307      3 BHK      NaN         1805   3.0      3.0  134.00
# 13308      3 BHK  Baanise         1527   3.0      1.0  142.00
# 13309      3 BHK  IBityin         1675   3.0      NaN   92.13
# 13310      2 BHK      NaN         1050   2.0      2.0   52.71
# 13311  7 Bedroom      NaN         1500   9.0      2.0  250.00
# 13312      2 BHK      NaN         1262   2.0      2.0   47.00
# 13313      3 BHK  Aklia R         1345   2.0      1.0   57.00
# 13314      3 BHK  SoosePr         1715   3.0      3.0  112.00
# 13315  5 Bedroom  ArsiaEx         3453   4.0      0.0  231.00
# 13316      4 BHK      NaN         3600   5.0      NaN  400.00
# 13317      2 BHK  Mahla T         1141   2.0      1.0   60.00
# 13318      4 BHK  SollyCl         4689   4.0      1.0  488.00
# 13319      1 BHK      NaN          550   1.0      1.0   17.00
#
# [13320 rows x 9 columns]

# %% [markdown]
# ## This is the updated dataset with latitudes and longitudes attached using foursquare which you can find in the coding part

# %%
df_bglr_300
# Out:
#                 area_type   availability  \
# 0    Super built-up  Area         19-Dec
# 1              Plot  Area  Ready To Move
# 2          Built-up  Area  Ready To Move
# 3    Super built-up  Area  Ready To Move
# 4    Super built-up  Area  Ready To Move
# 5    Super built-up  Area  Ready To Move
# 6    Super built-up  Area         18-May
# 7    Super built-up  Area  Ready To Move
# 8    Super built-up  Area  Ready To Move
# 9              Plot  Area  Ready To Move
# 10   Super built-up  Area         18-Feb
# 11             Plot  Area  Ready To Move
# 12   Super built-up  Area  Ready To Move
# 13         Built-up  Area  Ready To Move
# 14             Plot  Area  Ready To Move
# 15   Super built-up  Area  Ready To Move
# 16   Super built-up  Area  Ready To Move
# 17   Super built-up  Area  Ready To Move
# 18   Super built-up  Area  Ready To Move
# 19   Super built-up  Area  Ready To Move
# 20         Built-up  Area  Ready To Move
# 21   Super built-up  Area         19-Dec
# 22             Plot  Area  Ready To Move
# 23   Super built-up  Area  Ready To Move
# 24   Super built-up  Area         18-Nov
# 25   Super built-up  Area         18-May
# 26   Super built-up  Area  Ready To Move
# 27         Built-up  Area         20-Dec
# 28   Super built-up  Area         17-Oct
# 29   Super built-up  Area  Ready To Move
# ..                    ...            ...
# 116  Super built-up  Area  Ready To Move
# 117  Super built-up  Area         18-Dec
# 118  Super built-up  Area         18-Jun
# 119            Plot  Area  Ready To Move
# 120  Super built-up  Area  Ready To Move
# 121  Super built-up  Area  Ready To Move
# 122  Super built-up  Area         18-Mar
# 123        Built-up  Area  Ready To Move
# 124  Super built-up  Area         22-Dec
# 125        Built-up  Area  Ready To Move
# 126        Built-up  Area  Ready To Move
# 127  Super built-up  Area         22-Jan
# 128  Super built-up  Area  Ready To Move
# 129            Plot  Area  Ready To Move
# 130        Built-up  Area  Ready To Move
# 131            Plot  Area  Ready To Move
# 132  Super built-up  Area  Ready To Move
# 133            Plot  Area  Ready To Move
# 134  Super built-up  Area  Ready To Move
# 135        Built-up  Area  Ready To Move
# 136  Super built-up  Area         18-Aug
# 137  Super built-up  Area         19-Mar
# 138  Super built-up  Area         18-May
# 139  Super built-up  Area         19-Jan
# 140        Built-up  Area  Ready To Move
# 141  Super built-up  Area         19-Dec
# 142  Super built-up  Area  Ready To Move
# 143  Super built-up  Area  Ready To Move
# 144  Super built-up  Area         17-Jul
# 145  Super built-up  Area  Ready To Move
#
#                                      location       size  society  \
# 0                    Electronic City Phase II      2 BHK  Coomee
# 1                            Chikka Tirupathi  4 Bedroom  Theanmp
# 2                                 Uttarahalli      3 BHK      NaN
# 3                          Lingadheeranahalli      3 BHK  Soiewre
# 4                                    Kothanur      2 BHK      NaN
# 5                                  Whitefield      2 BHK  DuenaTa
# 6                            Old Airport Road      4 BHK  Jaades
# 7                                Rajaji Nagar      4 BHK  Brway G
# 8                                Marathahalli      3 BHK      NaN
# 9                                Gandhi Bazar  6 Bedroom      NaN
# 10                                 Whitefield      3 BHK      NaN
# 11                                 Whitefield  4 Bedroom  Prrry M
# 12                         7th Phase JP Nagar      2 BHK  Shncyes
# 13                                  Gottigere      2 BHK      NaN
# 14                                   Sarjapur  3 Bedroom  Skityer
# 15                                Mysore Road      2 BHK  PrntaEn
# 16                              Bisuvanahalli      3 BHK  Prityel
# 17                      Raja Rajeshwari Nagar      3 BHK  GrrvaGr
# 18                      Ramakrishnappa Layout      3 BHK  PeBayle
# 19                         Manayata Tech Park      2 BHK      NaN
# 20                                    Kengeri      1 BHK      NaN
# 21                                 Binny Pete      3 BHK  She 2rk
# 22                                Thanisandra  4 Bedroom  Soitya
# 23                                  Bellandur      3 BHK      NaN
# 24                                Thanisandra       1 RK  Bhe 2ko
# 25                            Mangammanapalya      3 BHK      NaN
# 26                            Electronic City      2 BHK  Itelaa
# 27                                 Whitefield      3 BHK      NaN
# 28                           Ramagondanahalli      2 BHK  ViistLa
# 29                            Electronic City      3 BHK  KBityo
# ..                                        ...        ...      ...
# 116                                   Kengeri      3 BHK  Vaens G
# 117                               Thanisandra      3 BHK      NaN
# 118                              Malleshwaram      2 BHK      NaN
# 119                               Hennur Road  2 Bedroom      NaN
# 120                               Thanisandra      3 BHK  Moity S
# 121                             Akshaya Nagar      3 BHK  HiahsLa
# 122                                    Hebbal      4 BHK  SNontle
# 123                                  Shampura      4 BHK      NaN
# 124                               Devanahalli      3 BHK  Sabixtt
# 125                                  Kadugodi      2 BHK      NaN
# 126                          LB Shastri Nagar      3 BHK  Sragei
# 127                               Vajarahalli      2 BHK      NaN
# 128                                   Hormavu      2 BHK  SyidaCr
# 129                        Vishwapriya Layout  7 Bedroom      NaN
# 130                                    Peenya      3 BHK  Jahts H
# 131                                  Sarjapur  3 Bedroom  Inensba
# 132                           Electronic City      2 BHK  Itelaa
# 133  Ramaswamy Palya - Kammanahalli Main Road  4 Bedroom      NaN
# 134                                Kudlu Gate      3 BHK  Srier P
# 135                            Kanakpura Road      2 BHK  Wiowsri
# 136                               Devanahalli      2 BHK  Derdsig
# 137                        8th Phase JP Nagar      2 BHK  Vaarech
# 138               Bommasandra Industrial Area      3 BHK      NaN
# 139                            Chandra Layout      3 BHK  TiaksAa
# 140                               Hennur Road  8 Bedroom      NaN
# 141                                 Yelahanka      5 BHK  LedorSa
# 142                              Kasavanhalli      3 BHK  HMwerCo
# 143                               ISRO Layout      2 BHK      NaN
# 144                                Anandapura      2 BHK  ViensRK
# 145                      Vishveshwarya Layout      7 BHK      NaN
#
#       total_sqft  bath  balcony    price   latitude  longitude
# 0           1056   2.0      1.0   39.070  12.846854  77.676927
# 1           2600   5.0      3.0  120.000  12.895768  77.867101
# 2           1440   2.0      3.0   62.000  12.905568  77.545544
# 3           1521   3.0      1.0   95.000  12.580537  77.333067
# 4           1200   2.0      1.0   51.000  44.373441 -71.610260
# 5           1170   2.0      1.0   38.000  25.709878  32.658512
# 6           2732   4.0      NaN  204.000  13.111516  80.211606
# 7           3300   4.0      NaN  600.000  12.955257  77.698416
# 8           1310   3.0      1.0   63.250  30.465678 -97.802748
# 9           1020   6.0      NaN  370.000  12.911881  77.578266
# 10          1800   2.0      2.0   70.000  12.856532  77.587724
# 11          2785   5.0      3.0  295.000  12.911623  77.638862
# 12          1000   2.0      1.0   38.000  51.461952  -0.159617
# 13          1100   2.0      2.0   40.000  17.334787  78.600878
# 14          2250   3.0      2.0  148.000  12.977895  77.516479
# 15          1175   2.0      2.0   73.500  12.917657  77.483757
# 16          1180   3.0      2.0   48.000  13.054713  77.633926
# 17          1540   3.0      3.0   60.000  12.936439  77.666984
# 18          2770   4.0      2.0  290.000  13.054713  77.633926
# 19          1100   2.0      2.0   48.000  12.895760  77.645701
# 20           600   1.0      1.0   15.000  32.293456 -64.782363
# 21          1755   3.0      1.0  122.000  13.439157  77.110180
# 22          2800   5.0      2.0  380.000  13.100698  77.596345
# 23          1767   3.0      1.0  103.000  13.038218  77.591900
# 24           510   1.0      0.0   25.250  13.004498  77.660323
# 25          1250   3.0      2.0   56.000  26.929200  75.703282
# 26           660   1.0      1.0   23.100  12.849678  77.664975
# 27          1610   3.0      2.0   81.000  12.968444  77.718784
# 28          1151   2.0      2.0   48.770  12.912192  77.547634
# 29          1025   2.0      1.0   47.000  12.958948  77.655593
# ..           ...   ...      ...      ...        ...        ...
# 116         1540   2.0      3.0   64.000  13.292399  77.751926
# 117         1436   3.0      1.0   74.750  13.097475  78.451659
# 118         1100   2.0      2.0   75.000  13.135140  77.749570
# 119          276   3.0      3.0   23.000  12.983634  77.708281
# 120         1427   3.0      2.0  120.000  12.851498  77.620410
# 121         2061   3.0      1.0  200.000  13.022142  77.640337
# 122  3067 - 8156   4.0      0.0  477.000  17.414849  78.495477
# 123         2650   4.0      2.0  150.000  13.014054  77.639424
# 124         1282   2.0      2.0   68.520  13.046754  77.632187
# 125         1050   2.0      1.0   34.000  13.008208  77.652392
# 126         1600   3.0      2.0   65.000  20.925258  77.740353
# 127          945   2.0      1.0   54.000  12.969909  77.711694
# 128         1500   2.0      1.0   78.000  13.036773  77.654948
# 129          950   7.0      0.0  115.000  13.050325  77.606080
# 130         1870   3.0      3.0  110.000  26.403498  82.607281
# 131         1600   3.0      1.0   75.000  12.888913  77.655572
# 132          880   1.0      1.0   16.500  13.074632  77.504859
# 133         1200   4.0      0.0  210.000  13.116015  80.231675
# 134         1535   3.0      2.0   83.000  12.898608  78.304619
# 135          950   2.0      1.0   57.000  12.785253  77.638093
# 136         1360   2.0      1.0   65.000  12.996525  77.563196
# 137  1042 - 1105   2.0      0.0   54.005  13.028038  77.723677
# 138         1280   3.0      1.0   50.400  12.984671  77.679091
# 139         1260   2.0      2.0   85.050  12.957002  77.721263
# 140         5000   8.0      NaN  250.000  12.910866  77.579045
# 141         3050   5.0      1.0  213.000  13.078474  77.606894
# 142      1563.05   3.0      1.0  105.000  13.009855  77.693089
# 143         1000   2.0      1.0   60.000  13.002655  77.634738
# 144         1167   2.0      1.0   43.760  13.029987  77.574051
# 145         4000   7.0      2.0  225.000  28.541034  77.264111
#
# [146 rows x 11 columns]

# %% [markdown]
# ## Description of the dataset

# %% [markdown]
# * **area_type**: describes the area's built up type.
# * **Availability**: Shows when will the appartment will be vacant.
# * **location**: describes the location of the appartment.
# * **size**: denotes the size of appartment whether 3BHK or 2BHk.
# * **Society**: shows the society of the appartment.
# * **Total_sqft**: denotes the measurements of the appartment on sqft's.
# * **bath**: denotes number of bathrooms available.
# * **balcony**: denotes the number of balcony's available.
# * **price**: denotes the price of the appartment.
# * **latitude**: denotes the latitude of the neighborhood
# * **longitude**: denotes the longitude of the neighborhood
